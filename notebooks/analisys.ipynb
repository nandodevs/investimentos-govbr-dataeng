# %%
import boto3
import pandas as pd
from io import StringIO
import os

# Configurações da AWS
account_key = os.getenv('AWS_ACCESS_KEY')
secret_key = os.getenv('AWS_SECRET_KEY')

# Inicializando o cliente S3
s3_client = boto3.client(
    's3',
    aws_access_key_id=account_key,
    aws_secret_access_key=secret_key,
    region_name='us-east-1'
)

# Nome do bucket e chave do arquivo no S3
bucket_name = 'investimentos-govbr'
object_key = 'raw/investimentos_2024.csv'

# Baixando o arquivo CSV do S3
response = s3_client.get_object(Bucket=bucket_name, Key=object_key)
csv_content = response['Body'].read().decode('latin1')  # Use o encoding correto

# Carregar o CSV no Pandas
data = pd.read_csv(StringIO(csv_content), delimiter=";")

# %%
try:
    # Baixando o arquivo CSV do S3
    response = s3_client.get_object(Bucket=bucket_name, Key=object_key)
    csv_content = response['Body'].read().decode('latin1')  # Use o encoding correto

    # Carregar o CSV no Pandas
    data = pd.read_csv(StringIO(csv_content), delimiter=";")

    # Exibir as primeiras linhas
    print(data.info())

except s3_client.exceptions.NoSuchKey as e:
    print(f"Erro: O arquivo com a chave {object_key} não foi encontrado no bucket {bucket_name}.")
except Exception as e:
    print(f"Erro inesperado: {str(e)}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16505 entries, 0 to 16504
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ano                       16505 non-null  int64
#  1   mes                       16505 non-null  object
#  2   esfera_orcamentaria       16505 non-null  int64
#  3   esfera_orcamentaria_desc  16505 non-null  object
#  4   orgao_maximo              16505 non-null  int64
#  5   orgao_maximo_desc         16505 non-null  object
#  6   uo                        16505 non-null  int64
#  7   uo_desc                   16505 non-null  object
#  8   grupo_despesa             16505 non-null  int64
#  9   grupo_despesa_desc        16505 non-null  object
#  10  aplicacao                 16505 non-null  int64
#  11  aplicacao_desc            16505 non-null  object
#  12  resultado                 16505 non-null  int64
#  13  resultado_desc            16505 non-null  object
#  14  funcao                    16505 non-null  int64
#  15  funcao_desc               16505 non-null  object
#  16  subfuncao                 16505 non-null  int64
#  17  subfuncao_desc            16505 non-null  object
#  18  programa                  16505 non-null  int64
#  19  programa_desc             16505 non-null  object
#  20  acao                      16505 non-null  object
#  21  acao_desc                 16505 non-null  object
#  22  regiao                    16505 non-null  object
#  23  uf                        16505 non-null  object
#  24  uf_desc                   16505 non-null  object
#  25  municipio                 16505 non-null  object
#  26  movimento_liquido_reais   16505 non-null  object
# dtypes: int64(10), object(17)
# memory usage: 3.4+ MB
# None

# %%
## Lendo Dados
data.head()
# Out:
#     ano      mes  esfera_orcamentaria esfera_orcamentaria_desc  orgao_maximo  \
# 0  2024  JANEIRO                    1         ORCAMENTO FISCAL          1000
# 1  2024  JANEIRO                    1         ORCAMENTO FISCAL          1000
# 2  2024  JANEIRO                    1         ORCAMENTO FISCAL          2000
# 3  2024  JANEIRO                    1         ORCAMENTO FISCAL          3000
# 4  2024  JANEIRO                    1         ORCAMENTO FISCAL         10000
#
#              orgao_maximo_desc     uo                      uo_desc  \
# 0         CAMARA DOS DEPUTADOS   1101         CAMARA DOS DEPUTADOS
# 1         CAMARA DOS DEPUTADOS   1101         CAMARA DOS DEPUTADOS
# 2               SENADO FEDERAL   2101               SENADO FEDERAL
# 3  TRIBUNAL DE CONTAS DA UNIAO   3101  TRIBUNAL DE CONTAS DA UNIAO
# 4     SUPREMO TRIBUNAL FEDERAL  10101     SUPREMO TRIBUNAL FEDERAL
#
#    grupo_despesa grupo_despesa_desc  ...       subfuncao_desc programa  \
# 0              4      INVESTIMENTOS  ...     ACAO LEGISLATIVA       34
# 1              4      INVESTIMENTOS  ...  ADMINISTRACAO GERAL       34
# 2              4      INVESTIMENTOS  ...     ACAO LEGISLATIVA       34
# 3              4      INVESTIMENTOS  ...     CONTROLE EXTERNO       34
# 4              4      INVESTIMENTOS  ...      ACAO JUDICIARIA       33
#
#                                        programa_desc  acao  \
# 0  PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGIS...  4061
# 1  PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGIS...  12F2
# 2  PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGIS...  4061
# 3  PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGIS...  4018
# 4  PROGRAMA DE GESTAO E MANUTENCAO DO PODER JUDIC...  6359
#
#                                            acao_desc        regiao   uf  \
# 0  PROCESSO LEGISLATIVO, FISCALIZACAO E REPRESENT...  CENTRO-OESTE   DF
# 1  REFORMA DOS IMOVEIS FUNCIONAIS DESTINADOS A MO...  CENTRO-OESTE   DF
# 2  PROCESSO LEGISLATIVO, FISCALIZACAO E REPRESENT...  CENTRO-OESTE   DF
# 3  FISCALIZACAO DA APLICACAO DOS RECURSOS PUBLICO...      NACIONAL  '-8
# 4  APRECIACAO E JULGAMENTO DE CAUSAS NO SUPREMO T...  CENTRO-OESTE   DF
#
#             uf_desc       municipio movimento_liquido_reais
# 0  DISTRITO FEDERAL        BRASILIA           1.024.768,40
# 1  DISTRITO FEDERAL        BRASILIA                  89,34
# 2  DISTRITO FEDERAL        BRASILIA           1.213.065,74
# 3    SEM INFORMACAO  SEM INFORMACAO             484.128,40
# 4  DISTRITO FEDERAL        BRASILIA             302.517,30
#
# [5 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['ano', 'mes', 'esfera_orcamentaria', 'esfera_orcamentaria_desc',
#        'orgao_maximo', 'orgao_maximo_desc', 'uo', 'uo_desc', 'grupo_despesa',
#        'grupo_despesa_desc', 'aplicacao', 'aplicacao_desc', 'resultado',
#        'resultado_desc', 'funcao', 'funcao_desc', 'subfuncao',
#        'subfuncao_desc', 'programa', 'programa_desc', 'acao', 'acao_desc',
#        'regiao', 'uf', 'uf_desc', 'municipio', 'movimento_liquido_reais'],
#       dtype='object')
